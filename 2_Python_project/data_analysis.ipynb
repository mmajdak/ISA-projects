# %% [markdown]
# ## Wczytanie danych i bibliotek

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# file = "ks_projects_201801.csv"
# filepath = os.path.join(os.path.abspath(""), file)

# %%
df = pd.read_csv("input_files/ks_projects_201801.csv")

# %% [markdown]
# ## Wstępne sprawdzenie danych

# %%
# Usunięcie wartości NaN
df = df.dropna()

# Ujednolicenie kolumn z datami, przekształcenie na format datetime
df['deadline_new'] = pd.to_datetime(df['deadline']).dt.date
df['launched_new'] = pd.to_datetime(df['launched']).dt.date

# Obliczenie czasu trwania projektów, oczyszczenie danych - przekształcenie na typ int
df['duration'] = df['deadline_new'] - df['launched_new']
df['duration'] = df['duration'].map(lambda x: int(str(x).split(" ")[0]))

# Wyodrębnienie dwóch stanów projektów: successful = 1, pozostałe = 0
df["state_new"] = df["state"].map(lambda x: 1 if x == "successful" else 0 )


df.sample(5)
# Out:
#                 ID                                               name  \
# 276756    47804765  Handicap Studios. Need to get studio finished ...
# 266402   425321155        IMAD Jewelry: Make A Difference for Animals
# 96348   1489621685            Hand Designed T-Shirts by Charles Arnes
# 308688   642407352                        Harrison Bonvissuto Solo Ep
# 310395   651089658  Frame, the new IOS and Android application for...
#
#           category main_category currency    deadline      goal  \
# 276756       Music         Music      USD  2014-09-21    4000.0
# 266402     Jewelry       Fashion      USD  2017-03-26    2000.0
# 96348      Fashion       Fashion      USD  2012-10-23    2500.0
# 308688  Indie Rock         Music      USD  2015-07-09    2000.0
# 310395        Apps    Technology      CHF  2017-02-21  150000.0
#
#                    launched  pledged   state  backers country  usd pledged  \
# 276756  2014-07-23 04:12:54      0.0  failed        0      US          0.0
# 266402  2017-02-24 16:51:43     27.0  failed        3      US          0.0
# 96348   2012-09-18 04:23:56    145.0  failed        3      US        145.0
# 308688  2015-06-09 15:53:35    245.0  failed        9      US        245.0
# 310395  2017-01-22 12:23:09    220.0  failed        3      CH        109.7
#
#         usd_pledged_real  usd_goal_real deadline_new launched_new  duration  \
# 276756              0.00        4000.00   2014-09-21   2014-07-23        60
# 266402             27.00        2000.00   2017-03-26   2017-02-24        30
# 96348             145.00        2500.00   2012-10-23   2012-09-18        35
# 308688            245.00        2000.00   2015-07-09   2015-06-09        30
# 310395            219.17      149432.16   2017-02-21   2017-01-22        30
#
#         state_new
# 276756          0
# 266402          0
# 96348           0
# 308688          0
# 310395          0

# %%
# df.columns

# %%
# Usunięcie niepotrzebnych kolumn
to_drop = ["currency",
           "deadline",
           "goal",
           "launched",
           "pledged",
           "state",
           "usd pledged"]

df.drop(to_drop, inplace=True, axis=1)

# %%
# df.head()

# %%
# Sprawdzenie, czy projekty się powtarzają
df["ID"].duplicated().any()
# Out:
# False

# %% [markdown]
# ## Ogólna analiza danych

# %%
# Sprawdzenie ile było projektów w poszczególnych krajach
project_country = dict(df["country"].value_counts())

# project_country

# %%
# Połączenie Luksemburga, Belgii i Holandii w Beneluks

df["country"] = df["country"].replace(["LU", "BE"],"NL")

project_country = dict(df["country"].value_counts())
# project_country

# %%
# Odrzucenie krajów, w których liczba projektów jest poniżej 1000

df = df[(df["country"] != "SG") 
        & (df["country"] != "JP") 
        & (df["country"] != "AT") 
        & (df["country"] != "HK")
        & (df["country"] != "NO")
        & (df["country"] != "CH")
        & (df["country"] != "IE")]
# df["country"].unique()

# %%
# Zaktualizowana liczba projektów w poszczególnych krajach

project_country_s = dict(df["country"].value_counts())
# project_country_s

# %%
# Odfiltrowanie projektów, które odniosły sukces w poszczególnych krajach

success_filter = df[df["state_new"] == 1]
group_success_filter = success_filter.groupby(by=["country"])
sum_success = dict(group_success_filter["state_new"].sum())

# sum_success

# %%
# Wizualizacja liczby projektów w poszczególnych krajch - sumarycznie i tych, które zdobyły finansowanie

all_country_list = []
success_country_list = []
country_list = []
for k, v in project_country_s.items():
    all_country_list.append(v)
    success_item = sum_success[k]
    success_country_list.append(success_item)
    country_list.append(k)
        
# print(all_country_list)
# print(success_country_list)
# print(country_list)

# %%
sns.set_theme(style="whitegrid")

# Ustawienia ogólne dla wykresu
f, ax = plt.subplots(figsize=(15, 10))
plt.title("Number of projects in selected countries", fontdict={'fontsize': 18})
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Number of projects', fontdict={'fontsize': 16})

# Wykres ogólnej liczby projektów
sns.set(font_scale=1.5)
sns.set_color_codes("pastel")
sns.barplot(x=country_list, y=all_country_list,
            label="Total", color="r")

# Wykres liczby projektów, które uzyskały finansowanie
sns.set_color_codes("muted")
sns.barplot(x=country_list, y=success_country_list,
            label="Succeed", color="r")

# Formatowanie legendy
ax.legend(ncol=2, loc="center right", frameon=True)
sns.despine(left=True, bottom=True)

# %%
# Procent projektów, które się udały

perc_success = {key: round(((sum_success[key] / project_country[key]) * 100), 1) for key, value in sum_success.items()}

# Procent projektów, które się udały - sortowanie wartości

perc_success_sort = {k: v for k, v in sorted(perc_success.items(), key=lambda item: item[1], reverse=True)}

# %%
# Wizualizacja odsetka sfinansowanych projektów w zależności od kraju

perc_country_list = []
country_list_2 = []
for country, perc in perc_success_sort.items():
    perc_country_list.append(perc)
    country_list_2.append(country)
        
# print(perc_country_list)
# print(country_list_2)

# %%
sns.set_theme(style="white", context="talk")

plt.figure(figsize=(15, 5))
plt.title("Percent of successful projects in selected countries", fontdict={'fontsize': 18})
plt.ylabel("Successful projects [%]", fontdict={'fontsize': 16})

sns.barplot(x=country_list_2, y=perc_country_list, palette="magma")

sns.despine(left=True);

# %% [markdown]
# #### Charakterystyka rozkładu liczby osób wspierających projekty

# %%
# Charakterystyka rozkładu liczby osób wspierających projekty

df.groupby(by="country")["backers"].describe().style.set_properties(**{'text-align':'center', 'padding':'15px'})
# Out:
# <style type="text/css">
# #T_9d124_row0_col0, #T_9d124_row0_col1, #T_9d124_row0_col2, #T_9d124_row0_col3, #T_9d124_row0_col4, #T_9d124_row0_col5, #T_9d124_row0_col6, #T_9d124_row0_col7, #T_9d124_row1_col0, #T_9d124_row1_col1, #T_9d124_row1_col2, #T_9d124_row1_col3, #T_9d124_row1_col4, #T_9d124_row1_col5, #T_9d124_row1_col6, #T_9d124_row1_col7, #T_9d124_row2_col0, #T_9d124_row2_col1, #T_9d124_row2_col2, #T_9d124_row2_col3, #T_9d124_row2_col4, #T_9d124_row2_col5, #T_9d124_row2_col6, #T_9d124_row2_col7, #T_9d124_row3_col0, #T_9d124_row3_col1, #T_9d124_row3_col2, #T_9d124_row3_col3, #T_9d124_row3_col4, #T_9d124_row3_col5, #T_9d124_row3_col6, #T_9d124_row3_col7, #T_9d124_row4_col0, #T_9d124_row4_col1, #T_9d124_row4_col2, #T_9d124_row4_col3, #T_9d124_row4_col4, #T_9d124_row4_col5, #T_9d124_row4_col6, #T_9d124_row4_col7, #T_9d124_row5_col0, #T_9d124_row5_col1, #T_9d124_row5_col2, #T_9d124_row5_col3, #T_9d124_row5_col4, #T_9d124_row5_col5, #T_9d124_row5_col6, #T_9d124_row5_col7, #T_9d124_row6_col0, #T_9d124_row6_col1, #T_9d124_row6_col2, #T_9d124_row6_col3, #T_9d124_row6_col4, #T_9d124_row6_col5, #T_9d124_row6_col6, #T_9d124_row6_col7, #T_9d124_row7_col0, #T_9d124_row7_col1, #T_9d124_row7_col2, #T_9d124_row7_col3, #T_9d124_row7_col4, #T_9d124_row7_col5, #T_9d124_row7_col6, #T_9d124_row7_col7, #T_9d124_row8_col0, #T_9d124_row8_col1, #T_9d124_row8_col2, #T_9d124_row8_col3, #T_9d124_row8_col4, #T_9d124_row8_col5, #T_9d124_row8_col6, #T_9d124_row8_col7, #T_9d124_row9_col0, #T_9d124_row9_col1, #T_9d124_row9_col2, #T_9d124_row9_col3, #T_9d124_row9_col4, #T_9d124_row9_col5, #T_9d124_row9_col6, #T_9d124_row9_col7, #T_9d124_row10_col0, #T_9d124_row10_col1, #T_9d124_row10_col2, #T_9d124_row10_col3, #T_9d124_row10_col4, #T_9d124_row10_col5, #T_9d124_row10_col6, #T_9d124_row10_col7, #T_9d124_row11_col0, #T_9d124_row11_col1, #T_9d124_row11_col2, #T_9d124_row11_col3, #T_9d124_row11_col4, #T_9d124_row11_col5, #T_9d124_row11_col6, #T_9d124_row11_col7, #T_9d124_row12_col0, #T_9d124_row12_col1, #T_9d124_row12_col2, #T_9d124_row12_col3, #T_9d124_row12_col4, #T_9d124_row12_col5, #T_9d124_row12_col6, #T_9d124_row12_col7 {
#   text-align: center;
#   padding: 15px;
# }
# </style>
# <table id="T_9d124_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d124_level0_row0" class="row_heading level0 row0" >AU</th>
#       <td id="T_9d124_row0_col0" class="data row0 col0" >7839.000000</td>
#       <td id="T_9d124_row0_col1" class="data row0 col1" >82.002296</td>
#       <td id="T_9d124_row0_col2" class="data row0 col2" >504.925487</td>
#       <td id="T_9d124_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9d124_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_9d124_row0_col5" class="data row0 col5" >6.000000</td>
#       <td id="T_9d124_row0_col6" class="data row0 col6" >38.000000</td>
#       <td id="T_9d124_row0_col7" class="data row0 col7" >20787.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row1" class="row_heading level0 row1" >CA</th>
#       <td id="T_9d124_row1_col0" class="data row1 col0" >14756.000000</td>
#       <td id="T_9d124_row1_col1" class="data row1 col1" >88.273448</td>
#       <td id="T_9d124_row1_col2" class="data row1 col2" >715.378241</td>
#       <td id="T_9d124_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_9d124_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_9d124_row1_col5" class="data row1 col5" >7.000000</td>
#       <td id="T_9d124_row1_col6" class="data row1 col6" >42.000000</td>
#       <td id="T_9d124_row1_col7" class="data row1 col7" >70122.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row2" class="row_heading level0 row2" >DE</th>
#       <td id="T_9d124_row2_col0" class="data row2 col0" >4171.000000</td>
#       <td id="T_9d124_row2_col1" class="data row2 col1" >98.333014</td>
#       <td id="T_9d124_row2_col2" class="data row2 col2" >488.289484</td>
#       <td id="T_9d124_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_9d124_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_9d124_row2_col5" class="data row2 col5" >6.000000</td>
#       <td id="T_9d124_row2_col6" class="data row2 col6" >39.000000</td>
#       <td id="T_9d124_row2_col7" class="data row2 col7" >12412.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row3" class="row_heading level0 row3" >DK</th>
#       <td id="T_9d124_row3_col0" class="data row3 col0" >1113.000000</td>
#       <td id="T_9d124_row3_col1" class="data row3 col1" >69.246181</td>
#       <td id="T_9d124_row3_col2" class="data row3 col2" >218.904155</td>
#       <td id="T_9d124_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_9d124_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_9d124_row3_col5" class="data row3 col5" >9.000000</td>
#       <td id="T_9d124_row3_col6" class="data row3 col6" >43.000000</td>
#       <td id="T_9d124_row3_col7" class="data row3 col7" >2749.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row4" class="row_heading level0 row4" >ES</th>
#       <td id="T_9d124_row4_col0" class="data row4 col0" >2276.000000</td>
#       <td id="T_9d124_row4_col1" class="data row4 col1" >72.155975</td>
#       <td id="T_9d124_row4_col2" class="data row4 col2" >330.955818</td>
#       <td id="T_9d124_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_9d124_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_9d124_row4_col5" class="data row4 col5" >5.000000</td>
#       <td id="T_9d124_row4_col6" class="data row4 col6" >37.000000</td>
#       <td id="T_9d124_row4_col7" class="data row4 col7" >9086.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row5" class="row_heading level0 row5" >FR</th>
#       <td id="T_9d124_row5_col0" class="data row5 col0" >2939.000000</td>
#       <td id="T_9d124_row5_col1" class="data row5 col1" >119.160939</td>
#       <td id="T_9d124_row5_col2" class="data row5 col2" >530.768091</td>
#       <td id="T_9d124_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_9d124_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_9d124_row5_col5" class="data row5 col5" >10.000000</td>
#       <td id="T_9d124_row5_col6" class="data row5 col6" >59.000000</td>
#       <td id="T_9d124_row5_col7" class="data row5 col7" >12103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row6" class="row_heading level0 row6" >GB</th>
#       <td id="T_9d124_row6_col0" class="data row6 col0" >33671.000000</td>
#       <td id="T_9d124_row6_col1" class="data row6 col1" >84.926940</td>
#       <td id="T_9d124_row6_col2" class="data row6 col2" >618.784137</td>
#       <td id="T_9d124_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_9d124_row6_col4" class="data row6 col4" >2.000000</td>
#       <td id="T_9d124_row6_col5" class="data row6 col5" >11.000000</td>
#       <td id="T_9d124_row6_col6" class="data row6 col6" >49.000000</td>
#       <td id="T_9d124_row6_col7" class="data row6 col7" >73206.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d124_level0_row7" class="row_heading level0 row7" >IT</th>
#       <td id="T_9d124_row7_col0" class="data row7 col0" >2878.000000</td>

# %%
# Wizualizacja rozkładu liczby osób wspierających projekty

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of the project's backers", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu liczby osób wspierających projekty
sns.boxplot(x=df["backers"], y=df["country"]);

ax.set_xlabel("Backers",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %%
# Usunięcie 5 % najwyższych wartości

df_95b = df[(df["backers"] < np.quantile(df["backers"],0.95))]

# %%
# Wizualizacja rozkładu liczby osób wspierających projekty

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution project's backers ( < 95 %)", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu liczby osób wspierających projekty
sns.boxplot(x=df_95b["backers"], y=df_95b["country"]);

ax.set_xlabel("Backers",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(15, 8))
plt.title("Distribution of project's backers ( < 95 %)", fontdict={'fontsize': 18})
plt.xlabel('Backers', fontdict={'fontsize': 15})
plt.ylabel("", fontdict={'fontsize': 15})
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

sns.histplot(df_95b["backers"], bins=100, kde=True, color="indigo");

# %% [markdown]
# #### Charakterystyka rozkładu liczby osób wspierających sfinansowane projekty

# %%
# Charakterystyka rozkładu liczby osób wspierających projekty, które uzyskały finansowanie

success_filter.groupby(by="country")["backers"].describe().style.set_properties(**{'text-align':'center', 'padding':'15px'})
# Out:
# <style type="text/css">
# #T_b56ea_row0_col0, #T_b56ea_row0_col1, #T_b56ea_row0_col2, #T_b56ea_row0_col3, #T_b56ea_row0_col4, #T_b56ea_row0_col5, #T_b56ea_row0_col6, #T_b56ea_row0_col7, #T_b56ea_row1_col0, #T_b56ea_row1_col1, #T_b56ea_row1_col2, #T_b56ea_row1_col3, #T_b56ea_row1_col4, #T_b56ea_row1_col5, #T_b56ea_row1_col6, #T_b56ea_row1_col7, #T_b56ea_row2_col0, #T_b56ea_row2_col1, #T_b56ea_row2_col2, #T_b56ea_row2_col3, #T_b56ea_row2_col4, #T_b56ea_row2_col5, #T_b56ea_row2_col6, #T_b56ea_row2_col7, #T_b56ea_row3_col0, #T_b56ea_row3_col1, #T_b56ea_row3_col2, #T_b56ea_row3_col3, #T_b56ea_row3_col4, #T_b56ea_row3_col5, #T_b56ea_row3_col6, #T_b56ea_row3_col7, #T_b56ea_row4_col0, #T_b56ea_row4_col1, #T_b56ea_row4_col2, #T_b56ea_row4_col3, #T_b56ea_row4_col4, #T_b56ea_row4_col5, #T_b56ea_row4_col6, #T_b56ea_row4_col7, #T_b56ea_row5_col0, #T_b56ea_row5_col1, #T_b56ea_row5_col2, #T_b56ea_row5_col3, #T_b56ea_row5_col4, #T_b56ea_row5_col5, #T_b56ea_row5_col6, #T_b56ea_row5_col7, #T_b56ea_row6_col0, #T_b56ea_row6_col1, #T_b56ea_row6_col2, #T_b56ea_row6_col3, #T_b56ea_row6_col4, #T_b56ea_row6_col5, #T_b56ea_row6_col6, #T_b56ea_row6_col7, #T_b56ea_row7_col0, #T_b56ea_row7_col1, #T_b56ea_row7_col2, #T_b56ea_row7_col3, #T_b56ea_row7_col4, #T_b56ea_row7_col5, #T_b56ea_row7_col6, #T_b56ea_row7_col7, #T_b56ea_row8_col0, #T_b56ea_row8_col1, #T_b56ea_row8_col2, #T_b56ea_row8_col3, #T_b56ea_row8_col4, #T_b56ea_row8_col5, #T_b56ea_row8_col6, #T_b56ea_row8_col7, #T_b56ea_row9_col0, #T_b56ea_row9_col1, #T_b56ea_row9_col2, #T_b56ea_row9_col3, #T_b56ea_row9_col4, #T_b56ea_row9_col5, #T_b56ea_row9_col6, #T_b56ea_row9_col7, #T_b56ea_row10_col0, #T_b56ea_row10_col1, #T_b56ea_row10_col2, #T_b56ea_row10_col3, #T_b56ea_row10_col4, #T_b56ea_row10_col5, #T_b56ea_row10_col6, #T_b56ea_row10_col7, #T_b56ea_row11_col0, #T_b56ea_row11_col1, #T_b56ea_row11_col2, #T_b56ea_row11_col3, #T_b56ea_row11_col4, #T_b56ea_row11_col5, #T_b56ea_row11_col6, #T_b56ea_row11_col7, #T_b56ea_row12_col0, #T_b56ea_row12_col1, #T_b56ea_row12_col2, #T_b56ea_row12_col3, #T_b56ea_row12_col4, #T_b56ea_row12_col5, #T_b56ea_row12_col6, #T_b56ea_row12_col7 {
#   text-align: center;
#   padding: 15px;
# }
# </style>
# <table id="T_b56ea_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b56ea_level0_row0" class="row_heading level0 row0" >AU</th>
#       <td id="T_b56ea_row0_col0" class="data row0 col0" >2010.000000</td>
#       <td id="T_b56ea_row0_col1" class="data row0 col1" >263.884577</td>
#       <td id="T_b56ea_row0_col2" class="data row0 col2" >939.511475</td>
#       <td id="T_b56ea_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_b56ea_row0_col4" class="data row0 col4" >33.000000</td>
#       <td id="T_b56ea_row0_col5" class="data row0 col5" >81.000000</td>
#       <td id="T_b56ea_row0_col6" class="data row0 col6" >195.000000</td>
#       <td id="T_b56ea_row0_col7" class="data row0 col7" >20787.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row1" class="row_heading level0 row1" >CA</th>
#       <td id="T_b56ea_row1_col0" class="data row1 col0" >4134.000000</td>
#       <td id="T_b56ea_row1_col1" class="data row1 col1" >267.064828</td>
#       <td id="T_b56ea_row1_col2" class="data row1 col2" >1326.294185</td>
#       <td id="T_b56ea_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_b56ea_row1_col4" class="data row1 col4" >30.000000</td>
#       <td id="T_b56ea_row1_col5" class="data row1 col5" >71.000000</td>
#       <td id="T_b56ea_row1_col6" class="data row1 col6" >180.000000</td>
#       <td id="T_b56ea_row1_col7" class="data row1 col7" >70122.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row2" class="row_heading level0 row2" >DE</th>
#       <td id="T_b56ea_row2_col0" class="data row2 col0" >937.000000</td>
#       <td id="T_b56ea_row2_col1" class="data row2 col1" >368.593383</td>
#       <td id="T_b56ea_row2_col2" class="data row2 col2" >971.497716</td>
#       <td id="T_b56ea_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_b56ea_row2_col4" class="data row2 col4" >35.000000</td>
#       <td id="T_b56ea_row2_col5" class="data row2 col5" >95.000000</td>
#       <td id="T_b56ea_row2_col6" class="data row2 col6" >274.000000</td>
#       <td id="T_b56ea_row2_col7" class="data row2 col7" >12412.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row3" class="row_heading level0 row3" >DK</th>
#       <td id="T_b56ea_row3_col0" class="data row3 col0" >360.000000</td>
#       <td id="T_b56ea_row3_col1" class="data row3 col1" >179.161111</td>
#       <td id="T_b56ea_row3_col2" class="data row3 col2" >336.140501</td>
#       <td id="T_b56ea_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_b56ea_row3_col4" class="data row3 col4" >24.000000</td>
#       <td id="T_b56ea_row3_col5" class="data row3 col5" >60.000000</td>
#       <td id="T_b56ea_row3_col6" class="data row3 col6" >158.250000</td>
#       <td id="T_b56ea_row3_col7" class="data row3 col7" >2749.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row4" class="row_heading level0 row4" >ES</th>
#       <td id="T_b56ea_row4_col0" class="data row4 col0" >492.000000</td>
#       <td id="T_b56ea_row4_col1" class="data row4 col1" >263.995935</td>
#       <td id="T_b56ea_row4_col2" class="data row4 col2" >667.250055</td>
#       <td id="T_b56ea_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_b56ea_row4_col4" class="data row4 col4" >37.000000</td>
#       <td id="T_b56ea_row4_col5" class="data row4 col5" >93.500000</td>
#       <td id="T_b56ea_row4_col6" class="data row4 col6" >237.500000</td>
#       <td id="T_b56ea_row4_col7" class="data row4 col7" >9086.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row5" class="row_heading level0 row5" >FR</th>
#       <td id="T_b56ea_row5_col0" class="data row5 col0" >908.000000</td>
#       <td id="T_b56ea_row5_col1" class="data row5 col1" >333.392070</td>
#       <td id="T_b56ea_row5_col2" class="data row5 col2" >898.243842</td>
#       <td id="T_b56ea_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_b56ea_row5_col4" class="data row5 col4" >40.000000</td>
#       <td id="T_b56ea_row5_col5" class="data row5 col5" >97.500000</td>
#       <td id="T_b56ea_row5_col6" class="data row5 col6" >245.000000</td>
#       <td id="T_b56ea_row5_col7" class="data row5 col7" >12103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row6" class="row_heading level0 row6" >GB</th>
#       <td id="T_b56ea_row6_col0" class="data row6 col0" >12067.000000</td>
#       <td id="T_b56ea_row6_col1" class="data row6 col1" >202.747162</td>
#       <td id="T_b56ea_row6_col2" class="data row6 col2" >1015.273428</td>
#       <td id="T_b56ea_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_b56ea_row6_col4" class="data row6 col4" >27.000000</td>
#       <td id="T_b56ea_row6_col5" class="data row6 col5" >59.000000</td>
#       <td id="T_b56ea_row6_col6" class="data row6 col6" >144.000000</td>
#       <td id="T_b56ea_row6_col7" class="data row6 col7" >73206.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b56ea_level0_row7" class="row_heading level0 row7" >IT</th>
#       <td id="T_b56ea_row7_col0" class="data row7 col

# %%
# Wizualizacja rozkładu liczby osób wspierających projekty, które uzyskały finansowanie

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of the successful project's backers", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu liczby osób wspierających projekty
sns.boxplot(x=success_filter["backers"], y=success_filter["country"]);

ax.set_xlabel("Backers",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %%
# Usunięcie 5 % najwyższych wartości

df_95bs = success_filter[(success_filter["backers"] < np.quantile(success_filter["backers"],0.95))]

# %%
# Wizualizacja rozkładu liczby osób wspierających projekty, które uzyskały finansowanie

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of successful project's backers ( < 95 %)", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu liczby osób wspierających projekty
sns.boxplot(x=df_95bs["backers"], y=df_95bs["country"]);

ax.set_xlabel("Backers",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(15, 8))
plt.title("Distribution of successful project's backers ( < 95 %)", fontdict={'fontsize': 18})
plt.xlabel('Backers', fontdict={'fontsize': 15})
plt.ylabel("", fontdict={'fontsize': 15})
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

sns.histplot(df_95bs["backers"], bins=100, kde=True, color="indigo");

# %% [markdown]
# ## Wyodrębnienie czynników mających wpływ na zakończenie projektu sukcesem

# %% [markdown]
# ### 1. Miesiąc rozpoczęcia zbiórki

# %%
# Wyodrębnienie roku i miesiąca z danych 

df['year_launched'] = pd.DatetimeIndex(df['launched_new']).year
df['month_launched'] = pd.DatetimeIndex(df['launched_new']).month
df['year_deadline'] = pd.DatetimeIndex(df['deadline_new']).year
df['month_deadline'] = pd.DatetimeIndex(df['deadline_new']).month
# df.head()

# %%
# Sprawdzenie ile projektów powstało w poszczególnych latach

df["year_launched"].value_counts()
# Out:
# 2015    74051
# 2014    66843
# 2016    55280
# 2017    50389
# 2013    44836
# 2012    41161
# 2011    26236
# 2010    10519
# 2009     1329
# 2018      120
# 1970        6
# Name: year_launched, dtype: int64

# %%
# Usunięcie rekordów z 1970 roku

df = df[df["year_launched"] != 1970]
# df["year_launched"].unique()

# %%
# Ile było rozpoczętych projektów w poszczególnych krajach w danym miesiącu
#
all_month_grouped = df.groupby(by=["country", "month_launched"]).size().reset_index(name="sum")

# Usuwam US z danych do Heatmap ze względu na to, że znacznie zawyża górną granicę danych (nie widać różnic w innych krajach)
all_month_grouped_us = all_month_grouped[all_month_grouped["country"] != "US"]

# %%
# Przygotowanie danych do Heatmap'y

df_month = all_month_grouped_us.pivot("country", "month_launched", "sum")
# df_month

# %%
# Wizualizacja liczby projektów w analizowanych krajach w poszczególnych miesiącach

fig, ax = plt.subplots(figsize=(15, 8))

plt.title("No. of projects", fontdict={'fontsize': 18})

sns.heatmap(df_month, fmt="d", annot=True, annot_kws={"fontsize":15}, linewidths=.5, cmap="RdPu")

ax.set_xlabel("Months",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("Countries",fontsize=15);

# %%
# Odfiltrowanie projektów, które uzyskały finansowanie

success_filter = df[df["state_new"] == 1]

month_grouped = success_filter.groupby(by=["country", "month_launched"]).size().reset_index(name="sum_success")

# %%
# Stworzenie tabeli z pogrupowanymi projektami

df_merge_month = pd.merge(all_month_grouped, month_grouped, on=["country", "month_launched"], how="left")

df_merge_month["perc_success"] = round(100 * df_merge_month["sum_success"] / df_merge_month["sum"], 2)

# %%
# Przygotowanie danych do Heatmap'y

df_month_perc = df_merge_month.pivot("country", "month_launched", "perc_success")

# %%
# Wizualizacja liczby sfinansowanych projektów w analizowanych krajach w poszczególnych miesiącach

fig, ax = plt.subplots(figsize=(15, 8))

plt.title("Pct. of funded projects", fontdict={'fontsize': 18})

sns.heatmap(df_month_perc, annot=True, annot_kws={"fontsize":15}, linewidths=.5, cmap="RdPu")

ax.set_xlabel("Months",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("Countries",fontsize=15);

# %% [markdown]
# #### W związku z tym, że nie ma wyraźnego trendu wskazującego na to, że w jakimś okresie szansa na uzyskanie finansowania projektu  jest większa (zarówno najmniejsze jak i największe wartości są rozdystrybułowane dość przypadkowo), nie bierzemy tej zależności pod uwagę w budowaniu aplikacji.

# %% [markdown]
# ### 2. Kategoria główna

# %%
df["main_category"].unique()
# Out:
# array(['Publishing', 'Film & Video', 'Music', 'Food', 'Design', 'Crafts',
#        'Games', 'Comics', 'Fashion', 'Theater', 'Art', 'Photography',
#        'Technology', 'Dance', 'Journalism'], dtype=object)

# %%
# Ile było projektów w poszczególnych krajach w danej kategorii

all_mcategory_grouped = df.groupby(by=["country", "main_category"]).size().reset_index(name="sum")

# Ile było projektów, które zostały sfinansowane w poszczególnych krajach w danej kategorii

mcategory_grouped = success_filter.groupby(by=["country", "main_category"]).size().reset_index(name="sum_success")

# Stworzenie tabeli z pogrupowanymi projektami i odsetkiem sfinansowanych projektów

df_merge_mcategory = pd.merge(all_mcategory_grouped, mcategory_grouped, on=["country", "main_category"], how="left")
df_merge_mcategory = df_merge_mcategory.fillna(0.0)
df_merge_mcategory["perc_success"] = round(100 * df_merge_mcategory["sum_success"] / df_merge_mcategory["sum"], 2)

# %%
# Wizualizacja odsetka sfinansowanych projektów w zależności od kategorii, w której projekt został złożony
sns.set_theme(style="white", context="talk")

fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Percent of successful projects in selected main categories (US)", fontdict={'fontsize': 18})

df_country = df_merge_mcategory[df_merge_mcategory["country"] == "US"]

sns.barplot(x="main_category", y="perc_success", palette="magma", data=df_country)

ax.set_xlabel("",fontsize=15)
ax.tick_params(labelsize=15, rotation=90)
ax.set_ylabel("Percent of founded projects [%]",fontsize=15)
sns.despine(left=True);

# %%
# Wizualizacja odsetka sfinansowanych projektów w zależności od kategorii, w której projekt został złożony
sns.set_theme(style="white", context="talk")

fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Percent of successful projects in selected main categories (GB)", fontdict={'fontsize': 18})

df_country = df_merge_mcategory[df_merge_mcategory["country"] == "GB"]

sns.barplot(x="main_category", y="perc_success", palette="magma", data=df_country)

ax.set_xlabel("",fontsize=15)
ax.tick_params(labelsize=15, rotation=90)
ax.set_ylabel("Percent of founded projects [%]",fontsize=15)
sns.despine(left=True);

# %%
# Wizualizacja odsetka sfinansowanych projektów w zależności od kategorii, w której projekt został złożony
sns.set_theme(style="white", context="talk")

fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Percent of successful projects in selected main categories (IT)", fontdict={'fontsize': 18})

df_country = df_merge_mcategory[df_merge_mcategory["country"] == "IT"]

sns.barplot(x="main_category", y="perc_success", palette="magma", data=df_country)

ax.set_xlabel("",fontsize=15)
ax.tick_params(labelsize=15, rotation=90)
ax.set_ylabel("Percent of founded projects [%]",fontsize=15)
sns.despine(left=True);

# %%
# Wizualizacja odsetka sfinansowanych projektów w zależności od kategorii, w której projekt został złożony
sns.set_theme(style="white", context="talk")

fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Percent of successful projects in selected main categories (MX)", fontdict={'fontsize': 18})

df_country = df_merge_mcategory[df_merge_mcategory["country"] == "MX"]

sns.barplot(x="main_category", y="perc_success", palette="magma", data=df_country)

ax.set_xlabel("",fontsize=15)
ax.tick_params(labelsize=15, rotation=90)
ax.set_ylabel("Percent of founded projects [%]",fontsize=15)
sns.despine(left=True);

# %% [markdown]
# #### We wszystkich państwach widać wyraźną zależność powodzenia projektu od tego w jakiej kategorii został złożony, więc kategoria będzie jednym z parametrów analizowanych w aplikacji.

# %% [markdown]
# ### 3. Podkategoria

# %%
# df["category"].unique()

# %%
# Ile było projektów w poszczególnych krajach w danej podkategorii

all_category_grouped = df.groupby(by=["country", "main_category", "category"]).size().reset_index(name="sum")

# Ile było projektów, które zostały sfinansowane w poszczególnych krajach w danej podkategorii

category_grouped = success_filter.groupby(by=["country", "main_category", "category"]).size().reset_index(name="sum_success")

# Stworzenie tabeli z pogrupowanymi projektami i odsetkiem sfinansowanych projektów

df_merge_category = pd.merge(all_category_grouped, category_grouped, on=["country", "main_category", "category"], how="left")
df_merge_category = df_merge_category.fillna(0.0)
df_merge_category["perc_success"] = round(100 * df_merge_category["sum_success"] / df_merge_category["sum"], 2)

# df_merge_category

# %%
# Wizualizacja odsetka sfinansowanych projektów w zależności od podkategorii, w której projekt został złożony

df_country_cat = df_merge_category[ df_merge_category["country"] == "US" ]

sns.set_theme(style="whitegrid")

fig, ax = plt.subplots(figsize=(6, 35))

plt.title("Percent of successful projects in selected categories", fontdict={'fontsize': 18})

sns.barplot(x="perc_success", y="category", hue="main_category", data=df_country_cat, dodge=False)

ax.legend(ncol=1, loc="lower right", frameon=True)
ax.set_xlabel("Percent of founded projects [%]",fontsize=15)
ax.tick_params(labelsize=12)
ax.set_ylabel("",fontsize=20)
sns.despine(left=True, bottom=True);

# %% [markdown]
# #### We wszystkich państwach widać wyraźną zależność powodzenia projektu od tego w jakiej podkategorii został złożony, więc podkategoria jest jednym z parametrów analizowanych w aplikacji.

# %% [markdown]
# ### 4. Czas trwania zbiórki

# %%
# Charakterystyka rozkładu czasu trwania projektów

df["duration"].describe().to_frame().style.set_properties(**{'padding':'15px'})
# Out:
# <style type="text/css">
# #T_a9836_row0_col0, #T_a9836_row1_col0, #T_a9836_row2_col0, #T_a9836_row3_col0, #T_a9836_row4_col0, #T_a9836_row5_col0, #T_a9836_row6_col0, #T_a9836_row7_col0 {
#   padding: 15px;
# }
# </style>
# <table id="T_a9836_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9836_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_a9836_row0_col0" class="data row0 col0" >370764.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_a9836_row1_col0" class="data row1 col0" >34.215121</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_a9836_row2_col0" class="data row2 col0" >12.817008</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_a9836_row3_col0" class="data row3 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_a9836_row4_col0" class="data row4 col0" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_a9836_row5_col0" class="data row5 col0" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_a9836_row6_col0" class="data row6 col0" >37.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9836_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_a9836_row7_col0" class="data row7 col0" >92.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Wizualizacja czasu trwania projektów w róznych krajach

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Duration of the project", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu czasu trwania projektów
sns.boxplot(x=df["duration"], y=df["country"]);

ax.set_xlabel("Days",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("Countries",fontsize=15)
sns.despine(left=True);

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(15, 8))
plt.title("Duration of the project", fontdict={'fontsize': 18})
plt.xlabel('Days', fontdict={'fontsize': 15})
plt.ylabel('No. of projects', fontdict={'fontsize': 15})
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

sns.histplot(df["duration"], bins=25, color="indigo");

# %%
# Charakterystyka rozkładu czasu trwania sfinansowanych projektów

success_filter["duration"].describe().to_frame().style.set_properties(**{'padding':'15px'})
# Out:
# <style type="text/css">
# #T_12ee1_row0_col0, #T_12ee1_row1_col0, #T_12ee1_row2_col0, #T_12ee1_row3_col0, #T_12ee1_row4_col0, #T_12ee1_row5_col0, #T_12ee1_row6_col0, #T_12ee1_row7_col0 {
#   padding: 15px;
# }
# </style>
# <table id="T_12ee1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12ee1_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_12ee1_row0_col0" class="data row0 col0" >132787.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_12ee1_row1_col0" class="data row1 col0" >32.154669</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_12ee1_row2_col0" class="data row2 col0" >11.783091</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_12ee1_row3_col0" class="data row3 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_12ee1_row4_col0" class="data row4 col0" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_12ee1_row5_col0" class="data row5 col0" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_12ee1_row6_col0" class="data row6 col0" >34.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12ee1_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_12ee1_row7_col0" class="data row7 col0" >92.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Wizualizacja czasu trwania sfinansowanych projektów

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Duration of the successful projects", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu czasu trwania projektów
sns.boxplot(x=success_filter["duration"], y=df["country"]);

ax.set_xlabel("Days",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("Countries",fontsize=15)
sns.despine(left=True);

# %% [markdown]
# #### Możliwe jest określenie przedziałów czasowych, które mogłyby zwiększyć prawdopodobieństwo zakończenia zbiórki sukcesem

# %% [markdown]
# ### 5. Kwota zbiórki

# %% [markdown]
# #### Charakterystyka rozkładu kwot zgłaszanych zbiórek

# %%
# Charakterystyka rozkładu kwot docelowych zgłaszanych projektów

df.groupby(by="country")["usd_goal_real"].describe().style.set_properties(**{'text-align':'center', 'padding':'15px'})
# Out:
# <style type="text/css">
# #T_e343a_row0_col0, #T_e343a_row0_col1, #T_e343a_row0_col2, #T_e343a_row0_col3, #T_e343a_row0_col4, #T_e343a_row0_col5, #T_e343a_row0_col6, #T_e343a_row0_col7, #T_e343a_row1_col0, #T_e343a_row1_col1, #T_e343a_row1_col2, #T_e343a_row1_col3, #T_e343a_row1_col4, #T_e343a_row1_col5, #T_e343a_row1_col6, #T_e343a_row1_col7, #T_e343a_row2_col0, #T_e343a_row2_col1, #T_e343a_row2_col2, #T_e343a_row2_col3, #T_e343a_row2_col4, #T_e343a_row2_col5, #T_e343a_row2_col6, #T_e343a_row2_col7, #T_e343a_row3_col0, #T_e343a_row3_col1, #T_e343a_row3_col2, #T_e343a_row3_col3, #T_e343a_row3_col4, #T_e343a_row3_col5, #T_e343a_row3_col6, #T_e343a_row3_col7, #T_e343a_row4_col0, #T_e343a_row4_col1, #T_e343a_row4_col2, #T_e343a_row4_col3, #T_e343a_row4_col4, #T_e343a_row4_col5, #T_e343a_row4_col6, #T_e343a_row4_col7, #T_e343a_row5_col0, #T_e343a_row5_col1, #T_e343a_row5_col2, #T_e343a_row5_col3, #T_e343a_row5_col4, #T_e343a_row5_col5, #T_e343a_row5_col6, #T_e343a_row5_col7, #T_e343a_row6_col0, #T_e343a_row6_col1, #T_e343a_row6_col2, #T_e343a_row6_col3, #T_e343a_row6_col4, #T_e343a_row6_col5, #T_e343a_row6_col6, #T_e343a_row6_col7, #T_e343a_row7_col0, #T_e343a_row7_col1, #T_e343a_row7_col2, #T_e343a_row7_col3, #T_e343a_row7_col4, #T_e343a_row7_col5, #T_e343a_row7_col6, #T_e343a_row7_col7, #T_e343a_row8_col0, #T_e343a_row8_col1, #T_e343a_row8_col2, #T_e343a_row8_col3, #T_e343a_row8_col4, #T_e343a_row8_col5, #T_e343a_row8_col6, #T_e343a_row8_col7, #T_e343a_row9_col0, #T_e343a_row9_col1, #T_e343a_row9_col2, #T_e343a_row9_col3, #T_e343a_row9_col4, #T_e343a_row9_col5, #T_e343a_row9_col6, #T_e343a_row9_col7, #T_e343a_row10_col0, #T_e343a_row10_col1, #T_e343a_row10_col2, #T_e343a_row10_col3, #T_e343a_row10_col4, #T_e343a_row10_col5, #T_e343a_row10_col6, #T_e343a_row10_col7, #T_e343a_row11_col0, #T_e343a_row11_col1, #T_e343a_row11_col2, #T_e343a_row11_col3, #T_e343a_row11_col4, #T_e343a_row11_col5, #T_e343a_row11_col6, #T_e343a_row11_col7, #T_e343a_row12_col0, #T_e343a_row12_col1, #T_e343a_row12_col2, #T_e343a_row12_col3, #T_e343a_row12_col4, #T_e343a_row12_col5, #T_e343a_row12_col6, #T_e343a_row12_col7 {
#   text-align: center;
#   padding: 15px;
# }
# </style>
# <table id="T_e343a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e343a_level0_row0" class="row_heading level0 row0" >AU</th>
#       <td id="T_e343a_row0_col0" class="data row0 col0" >7839.000000</td>
#       <td id="T_e343a_row0_col1" class="data row0 col1" >58108.238300</td>
#       <td id="T_e343a_row0_col2" class="data row0 col2" >1092073.826450</td>
#       <td id="T_e343a_row0_col3" class="data row0 col3" >0.720000</td>
#       <td id="T_e343a_row0_col4" class="data row0 col4" >1864.280000</td>
#       <td id="T_e343a_row0_col5" class="data row0 col5" >6279.300000</td>
#       <td id="T_e343a_row0_col6" class="data row0 col6" >18493.550000</td>
#       <td id="T_e343a_row0_col7" class="data row0 col7" >87092840.970000</td>
#     </tr>
#     <tr>
#       <th id="T_e343a_level0_row1" class="row_heading level0 row1" >CA</th>
#       <td id="T_e343a_row1_col0" class="data row1 col0" >14756.000000</td>
#       <td id="T_e343a_row1_col1" class="data row1 col1" >44408.442966</td>
#       <td id="T_e343a_row1_col2" class="data row1 col2" >1019377.575326</td>
#       <td id="T_e343a_row1_col3" class="data row1 col3" >0.730000</td>
#       <td id="T_e343a_row1_col4" class="data row1 col4" >1879.280000</td>
#       <td id="T_e343a_row1_col5" class="data row1 col5" >5761.375000</td>
#       <td id="T_e343a_row1_col6" class="data row1 col6" >17991.277500</td>
#       <td id="T_e343a_row1_col7" class="data row1 col7" >82624142.770000</td>
#     </tr>
#     <tr>
#       <th id="T_e343a_level0_row2" class="row_heading level0 row2" >DE</th>
#       <td id="T_e343a_row2_col0" class="data row2 col0" >4171.000000</td>
#       <td id="T_e343a_row2_col1" class="data row2 col1" >75208.408327</td>
#       <td id="T_e343a_row2_col2" class="data row2 col2" >1694473.699883</td>
#       <td id="T_e343a_row2_col3" class="data row2 col3" >1.080000</td>
#       <td id="T_e343a_row2_col4" class="data row2 col4" >2805.745000</td>
#       <td id="T_e343a_row2_col5" class="data row2 col5" >10606.030000</td>
#       <td id="T_e343a_row2_col6" class="data row2 col6" >27889.960000</td>
#       <td id="T_e343a_row2_col7" class="data row2 col7" >107369867.720000</td>
#     </tr>
#     <tr>
#       <th id="T_e343a_level0_row3" class="row_heading level0 row3" >DK</th>
#       <td id="T_e343a_row3_col0" class="data row3 col0" >1113.000000</td>
#       <td id="T_e343a_row3_col1" class="data row3 col1" >35581.350836</td>
#       <td id="T_e343a_row3_col2" class="data row3 col2" >439483.036630</td>
#       <td id="T_e343a_row3_col3" class="data row3 col3" >0.740000</td>
#       <td id="T_e343a_row3_col4" class="data row3 col4" >1487.940000</td>
#       <td id="T_e343a_row3_col5" class="data row3 col5" >5032.880000</td>
#       <td id="T_e343a_row3_col6" class="data row3 col6" >15078.180000</td>
#       <td id="T_e343a_row3_col7" class="data row3 col7" >14461315.980000</td>
#     </tr>
#     <tr>
#       <th id="T_e343a_level0_row4" class="row_heading level0 row4" >ES</th>
#       <td id="T_e343a_row4_col0" class="data row4 col0" >2276.000000</td>
#       <td id="T_e343a_row4_col1" class="data row4 col1" >52578.874587</td>
#       <td id="T_e343a_row4_col2" class="data row4 col2" >467681.145857</td>
#       <td id="T_e343a_row4_col3" class="data row4 col3" >1.040000</td>
#       <td id="T_e343a_row4_col4" class="data row4 col4" >2225.490000</td>
#       <td id="T_e343a_row4_col5" class="data row4 col5" >7025.715000</td>
#       <td id="T_e343a_row4_col6" class="data row4 col6" >23495.567500</td>
#       <td id="T_e343a_row4_col7" class="data row4 col7" >17104542.970000</td>
#     </tr>
#     <tr>
#       <th id="T_e343a_level0_row5" class="row_heading level0 row5" >FR</th>
#       <td id="T_e343a_row5_col0" class="data row5 col0" >2939.000000</td>
#       <td id="T_e343a_row5_col1" class="data row5 col1" >81047.372872</td>
#       <td id="T_e343a_row5_col2" class="data row5 col2" >2102100.094850</td>
#       <td id="T_e343a_row5_col3" class="data row5 col3" >1.090000</td>
#       <td id="T_e343a_row5_col4" class="data row5 col4" >2907.380000</td>
#       <td id="T_e343a_row5_col5" class="data row5 col5" >9521.680000</td>
#       <td id="T_e343a_row5_col6" class="data row5 col6" >26113.775000</td>
#       <td id="T_e343a_row5_col7" class="data row5 col7" >110169771.620000</td>
#     </tr>
#     <tr>
#       <th id="T_e343a_level0_row6" class="row_heading level0 row6" >GB</th>
#       <td id="T_e343a_row6_col0" class="data row6 col0" >33671.000000</td>
#       <td id="T_e343a_row6_col1" class="data row6 col1" >42775.298964</td>
#       <td id="T_e343a_row6_col2" class="data row6 col2" >1337027.959093</td>
#       <td id="T_e343a_row6_col3" class="data row6 col3" >1.220000</td>
#       <td id="T_e343a_row6_col4" class="data row6 col4" >1402.065000</td>
#       <td id="T_e343a_row6_col5" class="data row6 col5" >4745.860000</td>
#       <td id="T_e343a_row6_col6" class="data row6 col6" >15383.200000</td>
#       <td id="T_e343a_row6_col7" class="data row6 col7" >166361390.710000</td>
#     </tr>
#     <tr>
#       <th id="T_e

# %%
# Wizualizacja rozkładu kwot docelowych zgłaszanych projektów
sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of the project's target costs", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu kwot projektów w wybranych krajach
sns.boxplot(x=df["usd_goal_real"], y=df["country"]);

ax.set_xlabel("Goal [$]",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %%
# Usunięcie 5 % najwyższych wartości

df_95 = df[(df['usd_goal_real'] < np.quantile(df['usd_goal_real'],0.95))]

# %%
# Wizualizacja rozkładu kwot docelowych zgłaszanych projektów
sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of the project's target costs ( < 95 %)", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu kwot projektów w wybranych krajach
sns.boxplot(x=df_95["usd_goal_real"], y=df_95["country"]);

ax.set_xlabel("Goal [$]",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %% [markdown]
# #### Charakterystyka rozkładu kwot sfinansowanych zbiórek

# %%
# Charakterystyka rozkładu kwot zebranych zgłaszanych projektów

df.groupby(by="country")["usd_pledged_real"].describe().style.set_properties(**{'text-align':'center', 'padding':'15px'})
# Out:
# <style type="text/css">
# #T_52d24_row0_col0, #T_52d24_row0_col1, #T_52d24_row0_col2, #T_52d24_row0_col3, #T_52d24_row0_col4, #T_52d24_row0_col5, #T_52d24_row0_col6, #T_52d24_row0_col7, #T_52d24_row1_col0, #T_52d24_row1_col1, #T_52d24_row1_col2, #T_52d24_row1_col3, #T_52d24_row1_col4, #T_52d24_row1_col5, #T_52d24_row1_col6, #T_52d24_row1_col7, #T_52d24_row2_col0, #T_52d24_row2_col1, #T_52d24_row2_col2, #T_52d24_row2_col3, #T_52d24_row2_col4, #T_52d24_row2_col5, #T_52d24_row2_col6, #T_52d24_row2_col7, #T_52d24_row3_col0, #T_52d24_row3_col1, #T_52d24_row3_col2, #T_52d24_row3_col3, #T_52d24_row3_col4, #T_52d24_row3_col5, #T_52d24_row3_col6, #T_52d24_row3_col7, #T_52d24_row4_col0, #T_52d24_row4_col1, #T_52d24_row4_col2, #T_52d24_row4_col3, #T_52d24_row4_col4, #T_52d24_row4_col5, #T_52d24_row4_col6, #T_52d24_row4_col7, #T_52d24_row5_col0, #T_52d24_row5_col1, #T_52d24_row5_col2, #T_52d24_row5_col3, #T_52d24_row5_col4, #T_52d24_row5_col5, #T_52d24_row5_col6, #T_52d24_row5_col7, #T_52d24_row6_col0, #T_52d24_row6_col1, #T_52d24_row6_col2, #T_52d24_row6_col3, #T_52d24_row6_col4, #T_52d24_row6_col5, #T_52d24_row6_col6, #T_52d24_row6_col7, #T_52d24_row7_col0, #T_52d24_row7_col1, #T_52d24_row7_col2, #T_52d24_row7_col3, #T_52d24_row7_col4, #T_52d24_row7_col5, #T_52d24_row7_col6, #T_52d24_row7_col7, #T_52d24_row8_col0, #T_52d24_row8_col1, #T_52d24_row8_col2, #T_52d24_row8_col3, #T_52d24_row8_col4, #T_52d24_row8_col5, #T_52d24_row8_col6, #T_52d24_row8_col7, #T_52d24_row9_col0, #T_52d24_row9_col1, #T_52d24_row9_col2, #T_52d24_row9_col3, #T_52d24_row9_col4, #T_52d24_row9_col5, #T_52d24_row9_col6, #T_52d24_row9_col7, #T_52d24_row10_col0, #T_52d24_row10_col1, #T_52d24_row10_col2, #T_52d24_row10_col3, #T_52d24_row10_col4, #T_52d24_row10_col5, #T_52d24_row10_col6, #T_52d24_row10_col7, #T_52d24_row11_col0, #T_52d24_row11_col1, #T_52d24_row11_col2, #T_52d24_row11_col3, #T_52d24_row11_col4, #T_52d24_row11_col5, #T_52d24_row11_col6, #T_52d24_row11_col7, #T_52d24_row12_col0, #T_52d24_row12_col1, #T_52d24_row12_col2, #T_52d24_row12_col3, #T_52d24_row12_col4, #T_52d24_row12_col5, #T_52d24_row12_col6, #T_52d24_row12_col7 {
#   text-align: center;
#   padding: 15px;
# }
# </style>
# <table id="T_52d24_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52d24_level0_row0" class="row_heading level0 row0" >AU</th>
#       <td id="T_52d24_row0_col0" class="data row0 col0" >7839.000000</td>
#       <td id="T_52d24_row0_col1" class="data row0 col1" >5962.128806</td>
#       <td id="T_52d24_row0_col2" class="data row0 col2" >32977.498647</td>
#       <td id="T_52d24_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_52d24_row0_col4" class="data row0 col4" >8.225000</td>
#       <td id="T_52d24_row0_col5" class="data row0 col5" >221.730000</td>
#       <td id="T_52d24_row0_col6" class="data row0 col6" >2396.295000</td>
#       <td id="T_52d24_row0_col7" class="data row0 col7" >1121309.260000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row1" class="row_heading level0 row1" >CA</th>
#       <td id="T_52d24_row1_col0" class="data row1 col0" >14756.000000</td>
#       <td id="T_52d24_row1_col1" class="data row1 col1" >6220.748131</td>
#       <td id="T_52d24_row1_col2" class="data row1 col2" >42598.719983</td>
#       <td id="T_52d24_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_52d24_row1_col4" class="data row1 col4" >7.840000</td>
#       <td id="T_52d24_row1_col5" class="data row1 col5" >302.820000</td>
#       <td id="T_52d24_row1_col6" class="data row1 col6" >2734.732500</td>
#       <td id="T_52d24_row1_col7" class="data row1 col7" >2500533.660000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row2" class="row_heading level0 row2" >DE</th>
#       <td id="T_52d24_row2_col0" class="data row2 col0" >4171.000000</td>
#       <td id="T_52d24_row2_col1" class="data row2 col1" >9536.387924</td>
#       <td id="T_52d24_row2_col2" class="data row2 col2" >46103.256337</td>
#       <td id="T_52d24_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_52d24_row2_col4" class="data row2 col4" >10.890000</td>
#       <td id="T_52d24_row2_col5" class="data row2 col5" >286.410000</td>
#       <td id="T_52d24_row2_col6" class="data row2 col6" >3037.440000</td>
#       <td id="T_52d24_row2_col7" class="data row2 col7" >1069748.490000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row3" class="row_heading level0 row3" >DK</th>
#       <td id="T_52d24_row3_col0" class="data row3 col0" >1113.000000</td>
#       <td id="T_52d24_row3_col1" class="data row3 col1" >6813.352713</td>
#       <td id="T_52d24_row3_col2" class="data row3 col2" >29354.053473</td>
#       <td id="T_52d24_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_52d24_row3_col4" class="data row3 col4" >14.270000</td>
#       <td id="T_52d24_row3_col5" class="data row3 col5" >372.510000</td>
#       <td id="T_52d24_row3_col6" class="data row3 col6" >2840.210000</td>
#       <td id="T_52d24_row3_col7" class="data row3 col7" >600707.310000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row4" class="row_heading level0 row4" >ES</th>
#       <td id="T_52d24_row4_col0" class="data row4 col0" >2276.000000</td>
#       <td id="T_52d24_row4_col1" class="data row4 col1" >5688.775738</td>
#       <td id="T_52d24_row4_col2" class="data row4 col2" >25347.197756</td>
#       <td id="T_52d24_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_52d24_row4_col4" class="data row4 col4" >2.127500</td>
#       <td id="T_52d24_row4_col5" class="data row4 col5" >157.305000</td>
#       <td id="T_52d24_row4_col6" class="data row4 col6" >2539.177500</td>
#       <td id="T_52d24_row4_col7" class="data row4 col7" >502621.740000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row5" class="row_heading level0 row5" >FR</th>
#       <td id="T_52d24_row5_col0" class="data row5 col0" >2939.000000</td>
#       <td id="T_52d24_row5_col1" class="data row5 col1" >11690.203409</td>
#       <td id="T_52d24_row5_col2" class="data row5 col2" >59201.303721</td>
#       <td id="T_52d24_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_52d24_row5_col4" class="data row5 col4" >17.725000</td>
#       <td id="T_52d24_row5_col5" class="data row5 col5" >540.860000</td>
#       <td id="T_52d24_row5_col6" class="data row5 col6" >4975.665000</td>
#       <td id="T_52d24_row5_col7" class="data row5 col7" >1764896.670000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row6" class="row_heading level0 row6" >GB</th>
#       <td id="T_52d24_row6_col0" class="data row6 col0" >33671.000000</td>
#       <td id="T_52d24_row6_col1" class="data row6 col1" >7026.433109</td>
#       <td id="T_52d24_row6_col2" class="data row6 col2" >56074.644061</td>
#       <td id="T_52d24_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_52d24_row6_col4" class="data row6 col4" >29.030000</td>
#       <td id="T_52d24_row6_col5" class="data row6 col5" >506.200000</td>
#       <td id="T_52d24_row6_col6" class="data row6 col6" >3203.640000</td>
#       <td id="T_52d24_row6_col7" class="data row6 col7" >5494492.810000</td>
#     </tr>
#     <tr>
#       <th id="T_52d24_level0_row7" class="row_heading level0 row7" >IT</th>

# %%
# Wizualizacja rozkładu kwot zebranych zgłaszanych projektów

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of the collected amount of money", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu zebranych kwot projektów w wybranych krajach
sns.boxplot(x=df["usd_pledged_real"], y=df["country"]);

ax.set_xlabel("Collected [$]",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %%
# Usunięcie 5 % najwyższych wartości

df_95p = df[(df['usd_pledged_real'] < np.quantile(df['usd_pledged_real'],0.95))]

# %%
# Wizualizacja rozkładu kwot zebranych zgłaszanych projektów

sns.set_theme(style="whitegrid")

# Ogólne ustawienia dla wykresu
fig, ax = plt.subplots(figsize=(15, 5))

plt.title("Distribution of the collected amount of money ( < 95 %)", fontdict={'fontsize': 18})

# Wykres skrzynkowy dla rozkładu zebranych kwot projektów w wybranych krajach
sns.boxplot(x=df_95p["usd_pledged_real"], y=df_95p["country"]);

ax.set_xlabel("Collected [$]",fontsize=15)
ax.tick_params(labelsize=15)
ax.set_ylabel("",fontsize=15)
sns.despine(left=True);

# %% [markdown]
# #### Zadeklarowaną kwotę projektu należy uznać za czynnik mający wpływ na jego powodzenie
